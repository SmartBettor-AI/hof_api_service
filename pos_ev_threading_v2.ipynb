# %%
import redis
import pandas as pd

# %%
redis_client = redis.Redis(host='localhost', port=6379, db=0)

# %%
def read_cached_df(path):
    serialized_df = redis_client.get(path)
    if serialized_df:
      serialized_df = serialized_df.decode('utf-8')
      cached_df = pd.read_json(serialized_df)
      return cached_df
    else:
      raise FileNotFoundError(f"No cached DataFrame found at path: {path}")
    
df = read_cached_df("pos_ev_b5b20918314d95ea0d34ea75f534f3b4")
print(df)
# Out:
#                                                outcome  fanduel  \
# 19   alternate_spreads_1st_5_innings_Atlanta Braves...      0.0
# 162              batter_home_runs_Over_Trea Turner_0.5     21.0
# 160               batter_home_runs_Over_Matt Olson_0.5     17.0
# 22   alternate_spreads_1st_5_innings_Philadelphia P...      0.0
# 233          batter_total_bases_Over_J.T. Realmuto_1.5      4.7
# ..                                                 ...      ...
# 305                 batter_rbis_Over_Marcell Ozuna_0.5      0.0
# 325                   batter_rbis_Over_Gio Urshela_0.5      0.0
# 317                batter_rbis_Over_Ramón Laureano_1.5      0.0
# 331                   batter_rbis_Over_Johan Rojas_0.5      0.0
# 548            alternate_totals_1st_5_innings_Over_7.5      0.0
#
#                           market_key           outcome_name  \
# 19   alternate_spreads_1st_5_innings         Atlanta Braves
# 162                 batter_home_runs                   Over
# 160                 batter_home_runs                   Over
# 22   alternate_spreads_1st_5_innings  Philadelphia Phillies
# 233               batter_total_bases                   Over
# ..                               ...                    ...
# 305                      batter_rbis                   Over
# 325                      batter_rbis                   Over
# 317                      batter_rbis                   Over
# 331                      batter_rbis                   Over
# 548   alternate_totals_1st_5_innings                   Over
#
#     outcome_description outcome_point                     wagers  nordicbet  \
# 19                               -0.5        Atlanta Braves_-0.5        0.0
# 162         Trea Turner           0.5       Trea Turner_Over_0.5        0.0
# 160          Matt Olson           0.5        Matt Olson_Over_0.5        0.0
# 22                                0.5  Philadelphia Phillies_0.5        0.0
# 233       J.T. Realmuto           1.5     J.T. Realmuto_Over_1.5        0.0
# ..                  ...           ...                        ...        ...
# 305       Marcell Ozuna           0.5     Marcell Ozuna_Over_0.5        0.0
# 325         Gio Urshela           0.5       Gio Urshela_Over_0.5        0.0
# 317      Ramón Laureano           1.5    Ramón Laureano_Over_1.5        0.0
# 331         Johan Rojas           0.5       Johan Rojas_Over_0.5        0.0
# 548                               7.5                   Over_7.5        0.0
#
#      espnbet  pinnacle  ...   ev_power                      wager  market  \
# 19      1.03      2.51  ...  79.899734        Atlanta Braves_-0.5     NaN
# 162     0.00      6.25  ...  90.368920       Trea Turner_Over_0.5     NaN
# 160    10.50      6.00  ...  95.218131        Matt Olson_Over_0.5     NaN
# 22      8.50      1.57  ...   5.037273  Philadelphia Phillies_0.5     NaN
# 233     0.00      2.42  ...  29.837501     J.T. Realmuto_Over_1.5     NaN
# ..       ...       ...  ...        ...                        ...     ...
# 305     4.50      0.00  ...   6.709696     Marcell Ozuna_Over_0.5     NaN
# 325     4.80      0.00  ...   7.961589       Gio Urshela_Over_0.5     NaN
# 317     5.50      0.00  ...   9.345464    Ramón Laureano_Over_1.5     NaN
# 331     6.00      0.00  ...   7.359146       Johan Rojas_Over_0.5     NaN
# 548     8.00      0.00  ...   7.426262                   Over_7.5     NaN
#
#                 game_date  sport_league_display            market_display  \
# 19   2024-08-30T22:41:00Z                   MLB  1st 5 Innings Alt Spread
# 162  2024-08-30T22:41:00Z                   MLB          Batter Home Runs
# 160  2024-08-30T22:41:00Z                   MLB          Batter Home Runs
# 22   2024-08-30T22:41:00Z                   MLB  1st 5 Innings Alt Spread
# 233  2024-08-30T22:41:00Z                   MLB        Batter Total Bases
# ..                    ...                   ...                       ...
# 305  2024-08-30T22:41:00Z                   MLB               Batter RBIs
# 325  2024-08-30T22:41:00Z                   MLB               Batter RBIs
# 317  2024-08-30T22:41:00Z                   MLB               Batter RBIs
# 331  2024-08-30T22:41:00Z                   MLB               Batter RBIs
# 548  2024-08-30T22:41:00Z                   MLB   1st 5 Innings Alt Total
#
#                   wager_display         wager_display_other  sportsbooks_used  \
# 19          Atlanta Braves -0.5  Philadelphia Phillies +0.5        [Pinnacle]
# 162        Trea Turner Over 0.5       Trea Turner Under 0.5         [Fanduel]
# 160         Matt Olson Over 0.5        Matt Olson Under 0.5         [Fanduel]
# 22   Philadelphia Phillies +0.5         Atlanta Braves -0.5         [Espnbet]
# 233      J.T. Realmuto Over 1.5     J.T. Realmuto Under 1.5         [Fanduel]
# ..                          ...                         ...               ...
# 305      Marcell Ozuna Over 0.5     Marcell Ozuna Under 0.5  [Williamhill_Us]
# 325        Gio Urshela Over 0.5       Gio Urshela Under 0.5           [Fliff]
# 317     Ramón Laureano Over 1.5    Ramón Laureano Under 1.5           [Fliff]
# 331        Johan Rojas Over 0.5       Johan Rojas Under 0.5  [Williamhill_Us]
# 548                   Over +7.5                  Under +7.5         [Espnbet]
#
#               snapshot_time
# 19  2024-08-30 18:07:54.306
# 162 2024-08-30 18:07:54.306
# 160 2024-08-30 18:07:54.306
# 22  2024-08-30 18:07:54.306
# 233 2024-08-30 18:07:54.306
# ..                      ...
# 305 2024-08-30 18:07:54.306
# 325 2024-08-30 18:07:54.306
# 317 2024-08-30 18:07:54.306
# 331 2024-08-30 18:07:54.306
# 548 2024-08-30 18:07:54.306
#
# [253 rows x 95 columns]
# /var/folders/45/vvds_7n55h151_y61fjd1fmc0000gn/T/ipykernel_4915/2444418874.py:5: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   cached_df = pd.read_json(serialized_df)

# %%
def get_cache_expiration(cache_name):
    """
    Get the expiration time of a cache entry in Redis.

    :param redis_client: Redis client instance
    :param cache_name: Name of the cache (key) to check
    :return: Remaining time-to-live in seconds, or None if the key does not exist or has no expiration
    """
    ttl = redis_client.ttl(cache_name)
    
    if ttl == -1:
        return None  # The key exists but does not have an expiration time
    elif ttl == -2:
        return None  # The key does not exist
    else:
        return ttl  # The remaining time-to-live in seconds

cache_name = "pos_ev_b5b20918314d95ea0d34ea75f534f3b4"

expiration_seconds = get_cache_expiration(cache_name)
print(expiration_seconds)
# Out:
# 16361

# %%
16361 / 60 /60
# Out:
# 4.544722222222222

# %%
def write_to_cache(df, cache_path):
    
    if not df.index.is_unique:
        df = df.reset_index(drop=True)
    serialized_df = df.to_json()
    redis_client.set(cache_path, serialized_df)
    print(f"df written to: {cache_path}")
write_to_cache(pd.DataFrame(), 'americanfootball_ncaaf_pos_ev_cache')
# Out:
# df written to: americanfootball_ncaaf_pos_arb_cache

# %%
df = pd.read_csv("/Users/stefanfeiler/Desktop/PFL_10:_2023_PFL_World_ChampionshipNovember_23_November_23.csv")

# %%
def categorize_markets(df):
    def categorize(row):
        market = row['market'].lower()

        try:
          current_market_keys = row['market_key'].lower()
        except:
            current_market_keys = ['']

        if any(x in market for x in ['wins by']):
            return 'Method of Victory'
        
        if any(x in market for x in ['wins', 'draw']) or market in ['over', 'under'] or any(x in current_market_keys for x in ['h2h', 'totals']) or any(x in market for x in ['scorecards = no action', 'ends in a draw']):
            return 'Fight lines'
        
        if any(x in market for x in ['round', 'ends in round']):
            return 'Round props'
        
        
        
        return 'Other props'

    df['market_key'] = df.apply(categorize, axis=1)
    return df
new_df = categorize_markets(df)

# %%
def categorize_dropdown(df):
    def categorize(row):
        market = row['market'].lower()

        if 'wins by' in market and 'round' in market:
            return True
        else:
            return False

    df['dropdown'] = df.apply(categorize, axis=1)
    return df
new_df = categorize_dropdown(df)

# %%
new_df.to_csv("/Users/stefanfeiler/Desktop/MMA_NEW_TEST.csv", index= False)

# %%
new_df[['market', 'dropdown']]
# Out:
#                                    market  dropdown
# 0                            Clay Collard     False
# 1                   Olivier Aubin-Mercier     False
# 2                    Fight ends in a Draw     False
# 3                         Over 0.5 rounds     False
# 4                        Under 0.5 rounds     False
# ..                                    ...       ...
# 399                 Stirn wins in round 3     False
# 400                Blyden wins in round 3     False
# 401    Stirn wins by KO/TKO or Submission     False
# 402  Jesse Stirn (scorecards = no action)     False
# 403  Josh Blyden (scorecards = no action)     False
#
# [404 rows x 2 columns]

# %%
df = pd.read_csv("/Users/stefanfeiler/Desktop/UFC_Fight_Night:_Burns_vs._BradySeptember_6_September_6.csv")

# %%
desired_columns = [
    'DraftKings', 'BetMGM', 'Caesars', 'BetRivers', 'FanDuel', 'Bet365', 'Unibet', 'PointsBet', 
    'BetOnline', 'BetAnySports', 'BetUS', 'Cloudbet', 'Jazz', 'MyBookie', 'Pinnacle', 'SXBet', 
    'Bovada', 'Betway'
]

# Find which of the desired columns are actually present in the DataFrame
existing_columns = [col for col in desired_columns if col in df.columns]

# Compute the average only for the existing columns
df['avg_mkt_odds'] = df[existing_columns].mean(axis=1)

# %%
df['market']
# Out:
# 0                                    Gilbert Burns
# 1                                       Sean Brady
# 2                             Fight ends in a Draw
# 3                                  Over 1.5 rounds
# 4                                 Under 1.5 rounds
#                           ...
# 434          Fletcher wins in round 2 - Submission
# 435           Ramaska wins in round 3 - Submission
# 436          Fletcher wins in round 3 - Submission
# 437    Zygimantas Ramaska (scorecards = no action)
# 438       Nathan Fletcher (scorecards = no action)
# Name: market, Length: 439, dtype: object

# %%
import pandas as pd
import numpy as np

# Assuming we have a DataFrame 'df' with columns: 'game_id', 'market', 'avg_mkt_odds'

# Step 1: Filter for 'Over' or 'Under' and 'Rounds' markets
def mark_main_totals(df):
    def is_over_under_rounds(market):
        return market.str.contains(r'(Over|Under)', regex=True)

    filtered_df = df[is_over_under_rounds(df['market'])].copy()

    # Step 2: Extract round value
    filtered_df['round_value'] = filtered_df['market'].str.extract(r'(\d+\.?\d*)')[0].astype(float)

    # Step 3: Group by game_id and round_value, then sum the avg_mkt_odds
    grouped = filtered_df.groupby(['game_id', 'round_value'])['avg_mkt_odds'].sum().reset_index()

    # Step 4: Find the round value with the lowest sum for each game
    lowest_rounds = grouped.loc[grouped.groupby('game_id')['avg_mkt_odds'].idxmin()]

    # Step 5: Merge this information back to the filtered DataFrame
    filtered_df = filtered_df.merge(lowest_rounds[['game_id', 'round_value']], 
                                    on=['game_id', 'round_value'], 
                                    how='left', 
                                    indicator=True)

    # Step 6: Mark the rows
    filtered_df['mark'] = np.where(filtered_df['_merge'] == 'both', 'Lowest Group', 'Other')
    filtered_df = filtered_df.drop('_merge', axis=1)

    # Step 7: Apply the marks to the original DataFrame
    df = df.merge(filtered_df[['game_id', 'market', 'mark']], 
                on=['game_id', 'market'], 
                how='left')

    # Fill NaN values in 'mark' column for rows that were not in the filtered DataFrame
    df['mark'] = df['mark'].fillna('Not Applicable')
    df = df.replace('Main Total Under', '')
    df = df.replace('Main Total Over', '')
    df['market_key'] = np.where(df['mark'] == 'Lowest Group', 'Main', df['market_key'])
    columns_to_drop = ['mark', 'mark_y', 'mark_x', 'avg_mkt_odds']
    for col in columns_to_drop:
        if col in df.columns:  # Check if the column exists before attempting to drop it
            df = df.drop(columns=col)
    return df
# Out:
#      Unnamed: 0            market  BetOnline    Bovada  Jazz  MyBookie  \
# 3             3   Over 1.5 rounds        NaN  1.153846   NaN       NaN
# 4             4  Under 1.5 rounds        NaN  5.000000   NaN       NaN
# 5             5   Over 2.5 rounds        NaN  1.322581   NaN       NaN
# 6             6  Under 2.5 rounds        NaN  3.250000   NaN       NaN
# 7             7   Over 3.5 rounds   1.454545  1.487805   NaN  1.476190
# 8             8  Under 3.5 rounds   2.800000  2.550000   NaN  2.490000
# 9             9   Over 4.5 rounds        NaN       NaN   NaN       NaN
# 10           10  Under 4.5 rounds        NaN       NaN   NaN       NaN
# 62           62   Over 1.5 rounds        NaN  1.307692   NaN       NaN
# 63           63  Under 1.5 rounds        NaN  3.300000   NaN       NaN
# 64           64   Over 2.5 rounds   1.571429  1.526316   NaN  1.523560
# 65           65  Under 2.5 rounds   2.450000  2.450000   NaN  2.360000
# 104         104   Over 1.5 rounds   2.500000  2.350000   NaN  2.320000
# 105         105  Under 1.5 rounds   1.555556  1.571429   NaN  1.543478
# 106         106   Over 2.5 rounds        NaN  3.900000   NaN       NaN
# 107         107  Under 2.5 rounds        NaN  1.229885   NaN       NaN
# 146         146   Over 2.5 rounds   2.550000       NaN   NaN       NaN
# 147         147  Under 2.5 rounds   1.540541       NaN   NaN       NaN
# 151         151   Over 1.5 rounds        NaN  1.363636   NaN       NaN
# 152         152  Under 1.5 rounds        NaN  3.000000   NaN       NaN
# 153         153   Over 2.5 rounds   1.689655  1.689655   NaN  1.746269
# 154         154  Under 2.5 rounds   2.150000  2.100000   NaN  1.970874
# 192         192   Over 1.5 rounds        NaN  1.526316   NaN       NaN
# 193         193  Under 1.5 rounds        NaN  2.450000   NaN       NaN
# 194         194   Over 2.5 rounds        NaN  2.100000   NaN  1.952381
# 195         195  Under 2.5 rounds        NaN  1.689655   NaN  1.763359
# 207         207   Over 1.5 rounds   2.150000  2.150000   NaN  2.170000
# 208         208  Under 1.5 rounds   1.689655  1.666667   NaN  1.613497
# 209         209   Over 2.5 rounds        NaN  3.550000   NaN       NaN
# 210         210  Under 2.5 rounds        NaN  1.277778   NaN       NaN
# 249         249   Over 1.5 rounds   3.750000  3.600000   NaN  3.460000
# 250         250  Under 1.5 rounds   1.285714  1.266667   NaN  1.263158
# 251         251   Over 2.5 rounds        NaN  8.000000   NaN       NaN
# 252         252  Under 2.5 rounds        NaN  1.071429   NaN       NaN
# 264         264   Over 1.5 rounds        NaN  1.222222   NaN       NaN
# 265         265  Under 1.5 rounds        NaN  4.000000   NaN       NaN
# 266         266   Over 2.5 rounds   1.416667  1.416667   NaN  1.392157
# 267         267  Under 2.5 rounds   2.900000  2.800000   NaN  2.780000
# 306         306   Over 1.5 rounds        NaN  1.333333   NaN       NaN
# 307         307  Under 1.5 rounds        NaN  3.200000   NaN       NaN
# 308         308   Over 2.5 rounds        NaN  1.606061   NaN       NaN
# 309         309  Under 2.5 rounds        NaN  2.250000   NaN       NaN
# 313         313   Over 1.5 rounds        NaN  1.250000   NaN       NaN
# 314         314  Under 1.5 rounds        NaN  3.750000   NaN       NaN
# 315         315   Over 2.5 rounds   1.476190  1.454545   NaN  1.442478
# 316         316  Under 2.5 rounds   2.700000  2.650000   NaN  2.590000
# 356         356   Over 1.5 rounds        NaN  1.285714   NaN       NaN
# 357         357  Under 1.5 rounds        NaN  3.500000   NaN       NaN
# 358         358   Over 2.5 rounds   1.555556  1.526316   NaN  1.510204
# 359         359  Under 2.5 rounds   2.500000  2.450000   NaN  2.390000
# 399         399   Over 1.5 rounds   1.625000  1.645161   NaN  1.561798
# 400         400  Under 1.5 rounds   2.300000  2.200000   NaN  2.280000
# 401         401   Over 2.5 rounds        NaN  2.450000   NaN       NaN
# 402         402  Under 2.5 rounds        NaN  1.526316   NaN       NaN
#
#      BetAnySports     BetUS  DraftKings  FanDuel  ...  highest_bettable_odds  \
# 3             NaN       NaN         NaN      NaN  ...               1.153846
# 4             NaN       NaN         NaN      NaN  ...               5.000000
# 5             NaN       NaN         NaN      NaN  ...               1.322581
# 6             NaN       NaN         NaN      NaN  ...               3.250000
# 7             NaN  1.454545    1.476190      NaN  ...               1.510204
# 8             NaN  2.800000    2.600000      NaN  ...               2.800000
# 9             NaN       NaN         NaN      NaN  ...               1.892857
# 10            NaN       NaN         NaN      NaN  ...               1.961538
# 62            NaN       NaN         NaN      NaN  ...               1.307692
# 63            NaN       NaN         NaN      NaN  ...               3.300000
# 64            NaN  1.571429    1.571429      NaN  ...               1.636943
# 65            NaN  2.450000    2.350000      NaN  ...               2.450000
# 104           NaN  2.500000    2.350000      NaN  ...               2.500000
# 105           NaN  1.555556    1.571429      NaN  ...               1.617284
# 106           NaN       NaN         NaN      NaN  ...               3.900000
# 107           NaN       NaN         NaN      NaN  ...               1.229885
# 146           NaN  2.550000         NaN      NaN  ...               2.550000
# 147           NaN  1.540541         NaN      NaN  ...               1.540541
# 151           NaN       NaN         NaN      NaN  ...               1.363636
# 152           NaN       NaN         NaN      NaN  ...               3.000000
# 153           NaN  1.689655    1.800000      NaN  ...               1.847458
# 154           NaN  2.150000    1.952381      NaN  ...               2.150000
# 192           NaN  1.555556         NaN      NaN  ...               1.555556
# 193           NaN  2.500000         NaN      NaN  ...               2.550000
# 194           NaN       NaN         NaN      NaN  ...               2.100000
# 195           NaN       NaN         NaN      NaN  ...               1.813008
# 207           NaN  2.150000    2.240000      NaN  ...               2.250000
# 208           NaN  1.689655    1.625000      NaN  ...               1.699301
# 209           NaN       NaN         NaN      NaN  ...               3.550000
# 210           NaN       NaN         NaN      NaN  ...               1.277778
# 249           NaN  3.500000    3.600000      NaN  ...               3.750000
# 250           NaN  1.285714    1.277778      NaN  ...               1.285714
# 251           NaN       NaN         NaN      NaN  ...               8.000000
# 252           NaN       NaN         NaN      NaN  ...               1.071429
# 264           NaN       NaN         NaN      NaN  ...               1.222222
# 265           NaN       NaN         NaN      NaN  ...               4.000000
# 266           NaN  1.454545    1.408163      NaN  ...               1.480769
# 267           NaN  2.800000    2.850000      NaN  ...               2.900000
# 306           NaN       NaN         NaN      NaN  ...               1.333333
# 307           NaN       NaN         NaN      NaN  ...               3.200000
# 308           NaN  1.625000         NaN      NaN  ...               1.699301
# 309           NaN  2.300000         NaN      NaN  ...               2.300000
# 313           NaN       NaN         NaN      NaN  ...               1.250000
# 314           NaN       NaN         NaN      NaN  ...               3.750000
# 315           NaN  1.476190    1.465116      NaN  ...               1.497512
# 316           NaN  2.700000    2.650000      NaN  ...               2.720000
# 356           NaN       NaN         NaN      NaN  ...               1.285714
# 357           NaN       NaN         NaN      NaN  ...               3.500000
# 358           NaN  1.555556    1.571429      NaN  ...               1.598802
# 359           NaN  2.500000    2.350000      NaN  ...               2.500000
# 399           NaN  1.666667    1.714286      NaN  ...               1.757576
# 400           NaN  2.200000    2.100000      NaN  ...               2.300000
# 401           NaN       NaN         NaN      NaN  ...               2.450000
# 402           NaN       NaN         NaN      NaN  ...               1.526316
#
#      average_bettable_odds                  sportsbooks_used  \
# 3                 1.153846                        ['Bovada']
# 4                 5.000000                        ['Bovada']
# 5                 1.322581                        ['Bovada']
# 6                 3.250000                        ['Bovada']
# 7                 1.476580                      ['Cloudbet']
# 8                 2.638333            ['Betonline', 'Betus']
# 9                 1.828108                      ['Pinnacle']
# 10                1.952467                      ['Pinnacle']
# 62                1.307692                        ['Bovada']
# 63                3.300000                        ['Bovada']
# 64                1.566077                      ['Cloudbet']
# 65                2.397500  ['Betonline', 'Betus', 'Bovada']
# 104               2.390000            ['Betonline', 'Betus']
# 105               1.570534                      ['Cloudbet']
# 106               3.900000                        ['Bovada']
# 107               1.229885                        ['Bovada']
# 146               2.550000            ['Betonline', 'Betus']
# 147               1.540541            ['Betonline', 'Betus']
# 151               1.363636                        ['Bovada']
# 152               3.000000                        ['Bovada']
# 153               1.750031                      ['Cloudbet']
# 154               2.051657            ['Betonline', 'Betus']
# 192               1.540804                         ['Betus']
# 193               2.500000                      ['Pinnacle']
# 194               2.028095                        ['Bovada']
# 195               1.736574                      ['Cloudbet']
# 207               2.181429                      ['Cloudbet']
# 208               1.656753                      ['Cloudbet']
# 209               3.550000                        ['Bovada']
# 210               1.277778                        ['Bovada']
# 249               3.570000                     ['Betonline']
# 250               1.272140            ['Betonline', 'Betus']
# 251               8.000000                        ['Bovada']
# 252               1.071429                        ['Bovada']
# 264               1.222222                        ['Bovada']
# 265               4.000000                        ['Bovada']
# 266               1.427432                      ['Cloudbet']
# 267               2.806250                     ['Betonline']
# 306               1.333333                        ['Bovada']
# 307               3.200000                        ['Bovada']
# 308               1.643051                      ['Cloudbet']
# 309               2.246000                         ['Betus']
# 313               1.250000                        ['Bovada']
# 314               3.750000                        ['Bovada']
# 315               1.465446                      ['Cloudbet']
# 316               2.667500                      ['Cloudbet']
# 356               1.285714                        ['Bovada']
# 357               3.500000                        ['Bovada']
# 358               1.551076                      ['Cloudbet']
# 359               2.433750            ['Betonline', 'Betus']
# 399               1.671294                      ['Cloudbet']
# 400               2.182500                     ['Betonline']
# 401               2.450000                        ['Bovada']
# 402               1.526316                        ['Bovada']
#
#            market_key                                               odds  \
# 3              totals  {"BetOnline": null, "Bovada": 1.15384615384615...
# 4              totals  {"BetOnline": null, "Bovada": 5.0, "Jazz": nul...
# 5              totals  {"BetOnline": null, "Bovada": 1.32258064516129...
# 6    Main Total Under  {"BetOnline": null, "Bovada": 3.25, "Jazz": nu...
# 7     Main Total Over  {"BetOnline": 1.4545454545454546, "Bovada": 1....
# 8              totals  {"BetOnline": 2.8, "Bovada": 2.55, "Jazz": nul...
# 9              totals  {"BetOnline": null, "Bovada": null, "Jazz": nu...
# 10             totals  {"BetOnline": null, "Bovada": null, "Jazz": nu...
# 62             totals  {"BetOnline": null, "Bovada": 1.30769230769230...
# 63   Main Total Under  {"BetOnline": null, "Bovada": 3.3, "Jazz": nul...
# 64    Main Total Over  {"BetOnline": 1.5714285714285714, "Bovada": 1....
# 65             totals  {"BetOnline": 2.45, "Bovada": 2.45, "Jazz": nu...
# 104   Main Total Over  {"BetOnline": 2.5, "Bovada": 2.35, "Jazz": nul...
# 105  Main Total Under  {"BetOnline": 1.5555555555555556, "Bovada": 1....
# 106            totals  {"BetOnline": null, "Bovada": 3.9, "Jazz": nul...
# 107            totals  {"BetOnline": null, "Bovada": 1.22988505747126...
# 146   Main Total Over  {"BetOnline": 2.55, "Bovada": null, "Jazz": nu...
# 147  Main Total Under  {"BetOnline": 1.5405405405405406, "Bovada": nu...
# 151            totals  {"BetOnline": null, "Bovada": 1.36363636363636...
# 152  Main Total Under  {"BetOnline": null, "Bovada": 3.0, "Jazz": nul...
# 153   Main Total Over  {"BetOnline": 1.6896551724137931, "Bovada": 1....
# 154            totals  {"BetOnline": 2.15, "Bovada": 2.1, "Jazz": nul...
# 192   Main Total Over  {"BetOnline": null, "Bovada": 1.52631578947368...
# 193  Main Total Under  {"BetOnline": null, "Bovada": 2.45, "Jazz": nu...
# 194            totals  {"BetOnline": null, "Bovada": 2.1, "Jazz": nul...
# 195            totals  {"BetOnline": null, "Bovada": 1.68965517241379...
# 207   Main Total Over  {"BetOnline": 2.15, "Bovada": 2.15, "Jazz": nu...
# 208  Main Total Under  {"BetOnline": 1.6896551724137931, "Bovada": 1....
# 209            totals  {"BetOnline": null, "Bovada": 3.55, "Jazz": nu...
# 210            totals  {"BetOnline": null, "Bovada": 1.27777777777777...
# 249            totals  {"BetOnline": 3.75, "Bovada": 3.6, "Jazz": nul...
# 250            totals  {"BetOnline": 1.2857142857142856, "Bovada": 1....
# 251            totals  {"BetOnline": null, "Bovada": 8.0, "Jazz": nul...
# 252            totals  {"BetOnline": null, "Bovada": 1.07142857142857...
# 264            totals  {"BetOnline": null, "Bovada": 1.22222222222222...
# 265            totals  {"BetOnline": null, "Bovada": 4.0, "Jazz": nul...
# 266   Main Total Over  {"BetOnline": 1.4166666666666667, "Bovada": 1....
# 267  Main Total Under  {"BetOnline": 2.9, "Bovada": 2.8, "Jazz": null...
# 306            totals  {"BetOnline": null, "Bovada": 1.33333333333333...
# 307  Main Total Under  {"BetOnline": null, "Bovada": 3.2, "Jazz": nul...
# 308   Main Total Over  {"BetOnline": null, "Bovada": 1.60606060606060...
# 309            totals  {"BetOnline": null, "Bovada": 2.25, "Jazz": nu...
# 313            totals  {"BetOnline": null, "Bovada": 1.25, "Jazz": nu...
# 314            totals  {"BetOnline": null, "Bovada": 3.75, "Jazz": nu...
# 315   Main Total Over  {"BetOnline": 1.4761904761904763, "Bovada": 1....
# 316  Main Total Under  {"BetOnline": 2.7, "Bovada": 2.65, "Jazz": nul...
# 356            totals  {"BetOnline": null, "Bovada": 1.28571428571428...
# 357  Main Total Under  {"BetOnline": null, "Bovada": 3.5, "Jazz": nul...
# 358   Main Total Over  {"BetOnline": 1.5555555555555556, "Bovada": 1....
# 359            totals  {"BetOnline": 2.5, "Bovada": 2.45, "Jazz": nul...
# 399   Main Total Over  {"BetOnline": 1.625, "Bovada": 1.6451612903225...
# 400  Main Total Under  {"BetOnline": 2.3, "Bovada": 2.2, "Jazz": null...
# 401            totals  {"BetOnline": null, "Bovada": 2.45, "Jazz": nu...
# 402            totals  {"BetOnline": null, "Bovada": 1.52631578947368...
#
#      market_type  dropdown avg_mkt_odds          mark_x mark_y
# 3    Fight lines         1     1.153846  Not Applicable    NaN
# 4    Fight lines         1     5.000000  Not Applicable    NaN
# 5    Fight lines         1     1.322581  Not Applicable    NaN
# 6    Fight lines         1     3.250000  Not Applicable    NaN
# 7    Fight lines         1     1.476580  Not Applicable    NaN
# 8    Fight lines         1     2.638333  Not Applicable    NaN
# 9    Fight lines         1     1.828108  Not Applicable    NaN
# 10   Fight lines         1     1.952467  Not Applicable    NaN
# 62   Fight lines         1     1.307692  Not Applicable    NaN
# 63   Fight lines         1     3.300000  Not Applicable    NaN
# 64   Fight lines         1     1.566077  Not Applicable    NaN
# 65   Fight lines         1     2.397500  Not Applicable    NaN
# 104  Fight lines         1     2.390000  Not Applicable    NaN
# 105  Fight lines         1     1.570534  Not Applicable    NaN
# 106  Fight lines         1     3.900000  Not Applicable    NaN
# 107  Fight lines         1     1.229885  Not Applicable    NaN
# 146  Fight lines         1     2.550000  Not Applicable    NaN
# 147  Fight lines         1     1.540541  Not Applicable    NaN
# 151  Fight lines         1     1.363636  Not Applicable    NaN
# 152  Fight lines         1     3.000000  Not Applicable    NaN
# 153  Fight lines         1     1.750031  Not Applicable    NaN
# 154  Fight lines         1     2.051657  Not Applicable    NaN
# 192  Fight lines         1     1.540804  Not Applicable    NaN
# 193  Fight lines         1     2.500000  Not Applicable    NaN
# 194  Fight lines         1     2.028095  Not Applicable    NaN
# 195  Fight lines         1     1.736574  Not Applicable    NaN
# 207  Fight lines         1     2.181429  Not Applicable    NaN
# 208  Fight lines         1     1.656753  Not Applicable    NaN
# 209  Fight lines         1     3.550000  Not Applicable    NaN
# 210  Fight lines         1     1.277778  Not Applicable    NaN
# 249  Fight lines         1     3.570000  Not Applicable    NaN
# 250  Fight lines         1     1.272140  Not Applicable    NaN
# 251  Fight lines         1     8.000000  Not Applicable    NaN
# 252  Fight lines         1     1.071429  Not Applicable    NaN
# 264  Fight lines         1     1.222222  Not Applicable    NaN
# 265  Fight lines         1     4.000000  Not Applicable    NaN
# 266  Fight lines         1     1.427432  Not Applicable    NaN
# 267  Fight lines         1     2.806250  Not Applicable    NaN
# 306  Fight lines         1     1.333333  Not Applicable    NaN
# 307  Fight lines         1     3.200000  Not Applicable    NaN
# 308  Fight lines         1     1.643051  Not Applicable    NaN
# 309  Fight lines         1     2.246000  Not Applicable    NaN
# 313  Fight lines         1     1.250000  Not Applicable    NaN
# 314  Fight lines         1     3.750000  Not Applicable    NaN
# 315  Fight lines         1     1.465446  Not Applicable    NaN
# 316  Fight lines         1     2.667500  Not Applicable    NaN
# 356  Fight lines         1     1.285714  Not Applicable    NaN
# 357  Fight lines         1     3.500000  Not Applicable    NaN
# 358  Fight lines         1     1.551076  Not Applicable    NaN
# 359  Fight lines         1     2.433750  Not Applicable    NaN
# 399  Fight lines         1     1.671294  Not Applicable    NaN
# 400  Fight lines         1     2.182500  Not Applicable    NaN
# 401  Fight lines         1     2.450000  Not Applicable    NaN
# 402  Fight lines         1     1.526316  Not Applicable    NaN
#
# [54 rows x 35 columns]
# /var/folders/45/vvds_7n55h151_y61fjd1fmc0000gn/T/ipykernel_92640/2072429332.py:8: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   return market.str.contains(r'(Over|Under)', regex=True)

# %%
df.to_csv("/Users/stefanfeiler/Desktop/UFC_Fight_Night:_Burns_vs._BradySeptember_6_September_6_TEST.csv")
